# %%
#task3
import pandas as pd

data = {
    "Name": ["Yersultan", "Kuanysh", "Arystan", "Danial", "Ruslan"],
    "Age": [19, 40, 15, 26, 5],
    "Score": [90, 75, 67, 34, 1]
}

df = pd.DataFrame(data)

# %%
#task4.1
print(df.head(3))
# Out:
#         Name  Age  Score
# 0  Yersultan   19     90
# 1    Kuanysh   40     75
# 2    Arystan   15     67

# %%
#task4.2
print(df.describe())
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   21.000000  53.400000
# std    13.057565  35.753322
# min     5.000000   1.000000
# 25%    15.000000  34.000000
# 50%    19.000000  67.000000
# 75%    26.000000  75.000000
# max    40.000000  90.000000

# %%
#task4.3
average = df["Score"].mean()
print("Average score:", average)
# Out:
# Average score: 53.4

# %%
#task5.1
older20 = df[df["Age"] > 20]
print(older20)
# Out:
#       Name  Age  Score
# 1  Kuanysh   40     75
# 3   Danial   26     34

# %%
#task5.2
score_above_80 = df[df["Score"] > 80]
print(score_above_80)
# Out:
#         Name  Age  Score
# 0  Yersultan   19     90
